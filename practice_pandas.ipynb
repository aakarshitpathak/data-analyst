# %%
import pandas as pd
import seaborn as sns

df= sns.get_dataset_names()
df
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df= sns.load_dataset("taxis")
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
''' Provides a statistical summary of numerical columns in a 
DataFrame or Series.'''

df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
df.info()
# Provides a concise summary of a DataFrame, focusing on its 
# structure and data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
# to calculate avg for any column here it is fare 

avg_fare= round(df['fare'].mean())
print(avg_fare)
# Out:
# 13

# %%
# to fill null values with given values from user 

df['fare']=df['fare'].fillna(avg_fare)

# %%
# to drop all the null values of payment

df=df.dropna(subset='payment')
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment             0
# pickup_zone        25
# dropoff_zone       44
# pickup_borough     25
# dropoff_borough    44
# dtype: int64

# %%
df=df.drop(columns='dropoff_borough')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df=df.set_index('dropoff')
df=df.drop(labels='2019-03-23 20:27:24')
df.head()
# Out:
# C:\Users\patha\AppData\Local\Temp\ipykernel_4388\3656767751.py:2: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df=df.drop(labels='2019-03-23 20:27:24')
#                      passengers  distance  fare   tip  tolls  total   color  \
# dropoff
# 2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0   9.30  yellow
# 2019-03-27 18:00:25           1      1.37   7.5  2.36    0.0  14.16  yellow
# 2019-03-10 01:49:51           1      7.70  27.0  6.15    0.0  36.95  yellow
# 2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0  13.40  yellow
# 2019-03-11 10:47:31           1      0.49   7.5  2.16    0.0  12.96  yellow
#
#                          payment                pickup_zone  \
# dropoff
# 2019-03-04 16:19:00         cash      Upper West Side South
# ...

# %%
rename = {
    'fare':'rupees'
}
df=df.rename(columns=rename)
df
# Out:
#                      passengers  distance  rupees   tip  tolls  total   color  \
# dropoff
# 2019-03-04 16:19:00           1      0.79     5.0  0.00    0.0   9.30  yellow
# 2019-03-27 18:00:25           1      1.37     7.5  2.36    0.0  14.16  yellow
# 2019-03-10 01:49:51           1      7.70    27.0  6.15    0.0  36.95  yellow
# 2019-03-30 13:37:14           3      2.16     9.0  1.10    0.0  13.40  yellow
# 2019-03-11 10:47:31           1      0.49     7.5  2.16    0.0  12.96  yellow
# ...                         ...       ...     ...   ...    ...    ...     ...
# 2019-03-31 09:55:27           1      0.75     4.5  1.06    0.0   6.36   green
# 2019-03-31 18:34:23           1     18.74    58.0  0.00    0.0  58.80   green
# 2019-03-23 23:14:25           1      4.14    16.0  0.00    0.0  17.30   green
# 2019-03-04 10:14:29           1      1.12     6.0  0.00    0.0   6.80   green
# 2019-03-13 19:48:02           1      3.85    15.0  3.36    0.0  20.16   green
#
# ...

# %% [markdown]
# - row wise selection
#     - iloc - index based selection
#     - loc - labes based selection
# - column wise selection
#     - single column selection
#         - dictionary like selection
#         - object column selection
#
#     - multiple column selection
#         - dictionary like selection

# %%
import pandas as pd

df = pd.read_csv("kc_house_data.csv")
df
df.iloc[2]
# Note: we use iloc when no unique id is given
# Out:
# id                    5631500400
# date             20150225T000000
# price                   180000.0
# bedrooms                       2
# bathrooms                    1.0
# sqft_living                  770
# sqft_lot                   10000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          6
# sqft_above                   770
# sqft_basement                  0
# yr_built                    1933
# yr_renovated                   0
# zipcode                    98028
# lat                      47.7379
# long                    -122.233
# sqft_living15               2720
# sqft_lot15                  8062
# Name: 2, dtype: object

# %%
df.iloc[21612]
# Out:
# id                    1523300157
# date             20141015T000000
# price                   325000.0
# bedrooms                       2
# bathrooms                   0.75
# sqft_living                 1020
# sqft_lot                    1076
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1020
# sqft_basement                  0
# yr_built                    2008
# yr_renovated                   0
# zipcode                    98144
# lat                      47.5941
# long                    -122.299
# sqft_living15               1020
# sqft_lot15                  1357
# Name: 21612, dtype: object

# %%
df.iloc[3:9]
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# 5    101930     1.0           0     0  ...     11        3890           1530
# 6      6819     2.0           0     0  ...      7        1715              0
# ...

# %%
df.iloc[3:9:2]
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 3  2487200875  20141209T000000   604000.0         4        3.0         1960
# 5  7237550310  20140512T000000  1225000.0         4        4.5         5420
# 7  2008000270  20150115T000000   291850.0         3        1.5         1060
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 3      5000     1.0           0     0  ...      7        1050            910
# 5    101930     1.0           0     0  ...     11        3890           1530
# 7      9711     1.0           0     0  ...      7        1060              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 3      1965             0    98136  47.5208 -122.393           1360
# 5      2001             0    98053  47.6561 -122.005           4760
# 7      1963             0    98198  47.4095 -122.315           1650
#
#    sqft_lot15
# 3        5000
# 5      101930
# 7        9711
#
# ...

# %%
df.iloc[[3,9,11,17,19]] 
# Note: IF YOU ARE DOING SLICING FOR PARTICULAR DATA THEN 
# DOUBLE BRACKETTS ARE NOT NECESSARY BUT IF YOU ARE GOING FOR
# MULTIPLE DATA THE DOUBLE BRACKETTS ARE NECESSARY

# %%
df.iloc[[2,4,7],[3,5,7]] #select specific rows and column
# Out:
#    bedrooms  sqft_living  floors
# 2         2          770     1.0
# 4         3         1680     1.0
# 7         3         1060     1.0

# %%
df = df.set_index('id') # this command is used to set command
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[5631500400] 
# Note: Use of loc- when there is unique id is given

# note: Data set ke andar jo bhi data hota hai woh label hota hai
# is liye loc ko hum label based selection bolte hai
# Out:
# date             20150225T000000
# price                   180000.0
# bedrooms                       2
# bathrooms                    1.0
# sqft_living                  770
# sqft_lot                   10000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          6
# sqft_above                   770
# sqft_basement                  0
# yr_built                    1933
# yr_renovated                   0
# zipcode                    98028
# lat                      47.7379
# long                    -122.233
# sqft_living15               2720
# sqft_lot15                  8062
# Name: 5631500400, dtype: object

# %%
df.loc[5631500400:1954400510]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 5631500400  20150225T000000  180000.0         2        1.0          770
# 2487200875  20141209T000000  604000.0         4        3.0         1960
# 1954400510  20150218T000000  510000.0         3        2.0         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# ...

# %%
# Multiple data selection
df.loc[[5631500400,2487200875]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 5631500400  20150225T000000  180000.0         2        1.0          770
# 2487200875  20141209T000000  604000.0         4        3.0         1960
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
#
#             sqft_living15  sqft_lot15
# id
# 5631500400           2720        8062
# 2487200875           1360        5000

# %%
#Dictionary like selection

# it is called so because in this we have selections like dictionary

df['price'] # single selection
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df[['price','bedrooms','bathrooms']]
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.price
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = sns.get_dataset_names()
df
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter only 1949 data
flights_1949 = df[df['year'] == 1949]

# Use barplot instead of countplot
fig = sns.barplot(data=flights_1949, x='month', y='passengers')

# Titles and labels
fig.set_title("Total Passengers Traveled in Each Month (1949)")
fig.set_xlabel("Months")
fig.set_ylabel("Number of Passengers")

plt.show()

# %%
# year wise total number of passengers travelled in flights

# group by year and sum passengers
yearly_pass=df.groupby('year')['passengers'].sum().reset_index()
print(yearly_pass) # to check the total 

fig=sns.histplot(data=yearly_pass,x='year',y='passengers')
fig.set_title("Passengers count by year")
fig.set_xlabel("Year")
fig.set_ylabel("Passengers count")

plt.show()
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
# year wise total number of passengers travelled in flights
# but by using bar plot 

yearly_pass=df.groupby('year')['passengers'].sum().reset_index()
print(yearly_pass)

# plot the bar m
fig=sns.barplot(data=yearly_pass,x='year',y='passengers')
fig.set_title("Passengers count by year")
fig.set_xlabel("Year")
fig.set_ylabel("Passengers count")

plt.show()
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714
